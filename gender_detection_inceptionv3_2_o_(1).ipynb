# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhishekSRM/Gender-Classification/blob/main/gender_detection_inceptionv3_2_o_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import cv2    
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score

from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.utils import np_utils
from keras.optimizers import SGD

from IPython.core.display import display, HTML
from PIL import Image
from io import BytesIO
import base64

plt.style.use('ggplot')

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.11.0-rc1

# %% [markdown]
# ## Step 1: Data Exploration (CelebA Dataset)

# %%
# set variables 
main_folder = '../input/celeba-dataset/'
images_folder = main_folder + 'img_align_celeba/img_align_celeba/'
EXAMPLE_PIC = images_folder + '000506.jpg'

TRAINING_SAMPLES = 10000
VALIDATION_SAMPLES = 2000
TEST_SAMPLES = 2000
IMG_WIDTH = 178
IMG_HEIGHT = 218
BATCH_SIZE = 10
NUM_EPOCHS = 40

# %% [markdown]
# ### Load the attributes of every picture
# File: list_attr_celeba.csv

# %%
df_attr = pd.read_csv(main_folder + 'list_attr_celeba.csv')
df_attr.set_index('image_id', inplace=True)
df_attr.replace(to_replace=-1, value=0, inplace=True) #replace -1 by 0
df_attr.shape
df_attr.head(5)
# Out:
#             5_o_Clock_Shadow  Arched_Eyebrows  ...    Wearing_Necktie  Young
# image_id                                       ...
# 000001.jpg                 0                1  ...                  0      1
# 000002.jpg                 0                0  ...                  0      1
# 000003.jpg                 0                0  ...                  0      1
# 000004.jpg                 0                0  ...                  0      1
# 000005.jpg                 0                1  ...                  0      1
#
# [5 rows x 40 columns]

# %% [markdown]
# ### List of the available attribute in the CelebA dataset
#
# 40 Attributes

# %%
# List of attributes
for i, j in enumerate(df_attr.columns):
    print(i, j)
# Out:
# 0 5_o_Clock_Shadow
# 1 Arched_Eyebrows
# 2 Attractive
# 3 Bags_Under_Eyes
# 4 Bald
# 5 Bangs
# 6 Big_Lips
# 7 Big_Nose
# 8 Black_Hair
# 9 Blond_Hair
# 10 Blurry
# 11 Brown_Hair
# 12 Bushy_Eyebrows
# 13 Chubby
# 14 Double_Chin
# 15 Eyeglasses
# 16 Goatee
# 17 Gray_Hair
# 18 Heavy_Makeup
# 19 High_Cheekbones
# 20 Male
# 21 Mouth_Slightly_Open
# 22 Mustache
# 23 Narrow_Eyes
# 24 No_Beard
# 25 Oval_Face
# 26 Pale_Skin
# 27 Pointy_Nose
# 28 Receding_Hairline
# 29 Rosy_Cheeks
# 30 Sideburns
# 31 Smiling
# 32 Straight_Hair
# 33 Wavy_Hair
# 34 Wearing_Earrings
# 35 Wearing_Hat
# 36 Wearing_Lipstick
# 37 Wearing_Necklace
# 38 Wearing_Necktie
# 39 Young

# %% [markdown]
# ### Example

# %%
img = load_img(EXAMPLE_PIC)
plt.grid(False)
plt.imshow(img)
df_attr.loc[EXAMPLE_PIC.split('/')[-1]][['Smiling','Male','Young']] #some attributes
# Out:
# Smiling    1
# Male       0
# Young      1
# Name: 000506.jpg, dtype: int64

# %% [markdown]
# ### Distribution

# %%
plt.title('Female or Male')
sns.countplot(y='Male', data=df_attr, color="c")
plt.show()

# %% [markdown]
# ## Step 2: Split Dataset into Training(1-162770), Validation(162771-182637) and Test(182638-202599)
#
# During time execution
#
# * Training 20000 images
# * Validation 5000 images
# * Test 5000 Images

# %%
df_partition = pd.read_csv(main_folder + 'list_eval_partition.csv')
df_partition.head()
# Out:
#      image_id  partition
# 0  000001.jpg          0
# 1  000002.jpg          0
# 2  000003.jpg          0
# 3  000004.jpg          0
# 4  000005.jpg          0

# %%
# 0 -> TRAINING
# 1 -> VALIDATION
# 2 -> TEST
df_partition['partition'].value_counts().sort_index()
# Out:
# 0    162770
# 1     19867
# 2     19962
# Name: partition, dtype: int64

# %% [markdown]
# #### Join the partition and the attributes in the same data frame

# %%
df_partition.set_index('image_id', inplace=True)
df_par_attr = df_partition.join(df_attr['Male'], how='inner')
df_par_attr.head()
# Out:
#             partition  Male
# image_id
# 000001.jpg          0     0
# 000002.jpg          0     0
# 000003.jpg          0     1
# 000004.jpg          0     0
# 000005.jpg          0     0

# %% [markdown]
# ### 2.1: Generate Partitions (Train, Validation, Test)

# %%
def load_reshape_img(fname):
    img = load_img(fname)
    x = img_to_array(img)/255.
    x = x.reshape((1,) + x.shape)

    return x


def generate_df(partition, attr, num_samples):
    '''
    partition
        0 -> train
        1 -> validation
        2 -> test
    
    '''
    
    df_ = df_par_attr[(df_par_attr['partition'] == partition) 
                           & (df_par_attr[attr] == 0)].sample(int(num_samples/2))
    df_ = pd.concat([df_,
                      df_par_attr[(df_par_attr['partition'] == partition) 
                                  & (df_par_attr[attr] == 1)].sample(int(num_samples/2))])

    # for Train and Validation
    if partition != 2:
        x_ = np.array([load_reshape_img(images_folder + fname) for fname in df_.index])
        x_ = x_.reshape(x_.shape[0], 218, 178, 3)
        y_ = np_utils.to_categorical(df_[attr],2)
    # for Test
    else:
        x_ = []
        y_ = []

        for index, target in df_.iterrows():
            im = cv2.imread(images_folder + index)
            im = cv2.resize(cv2.cvtColor(im, cv2.COLOR_BGR2RGB), (IMG_WIDTH, IMG_HEIGHT)).astype(np.float32) / 255.0
            im = np.expand_dims(im, axis =0)
            x_.append(im)
            y_.append(target[attr])

    return x_, y_

# %% [markdown]
# ##  Data Augmentation

# %%
# Generate image generator for data augmentation
datagen =  ImageDataGenerator(
  rotation_range=15,
  width_shift_range=0.3,
  height_shift_range=0.3,
  shear_range=0.3,
  zoom_range=0.3,
  horizontal_flip=True
)

# load one image and reshape
img = load_img(EXAMPLE_PIC)
x = img_to_array(img)/255.
x = x.reshape((1,) + x.shape)

# plot 10 augmented images of the loaded iamge
plt.figure(figsize=(20,10))
plt.suptitle('Data Augmentation', fontsize=28)

i = 0
for batch in datagen.flow(x, batch_size=1):
    plt.subplot(3, 5, i+1)
    plt.grid(False)
    plt.imshow( batch.reshape(218, 178, 3))
    
    if i == 9:
        break
    i += 1
    
plt.show()

# %% [markdown]
# ### 3.2. Build Data Generators

# %%
# Train data
x_train, y_train = generate_df(0, 'Male', TRAINING_SAMPLES)

# Train - Data Preparation - Data Augmentation with generators
train_datagen =  ImageDataGenerator(
  preprocessing_function=preprocess_input,
  rotation_range=15,
  width_shift_range=0.3,
  height_shift_range=0.3,
  shear_range=0.3,
  zoom_range=0.3,
  horizontal_flip=True,
)

train_datagen.fit(x_train)

train_generator = train_datagen.flow(
x_train, y_train,
batch_size=BATCH_SIZE,
)

# %%
# Validation Data
x_valid, y_valid = generate_df(1, 'Male', VALIDATION_SAMPLES)
# Out:
# '\n# Validation - Data Preparation - Data Augmentation with generators\nvalid_datagen = ImageDataGenerator(\n  preprocessing_function=preprocess_input,\n)\n\nvalid_datagen.fit(x_valid)\n\nvalidation_generator = valid_datagen.flow(\nx_valid, y_valid,\n)\n'

# %% [markdown]
# With the data generator created and data for validation, we are ready to start modeling.

# %% [markdown]
# ## Step 4: Build the Model - Gender Recognition

# %% [markdown]
# ### 4.1. Set the Model

# %%
# Imported InceptionV3 Model
inc_model = InceptionV3(weights='../input/inceptionv3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5',
                        include_top=False,
                        input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

print("number of layers:", len(inc_model.layers))
# Out:
# number of layers: 311

# %% [markdown]
# <h2>Inception-V3 model structure</h2>
#
#
#
# <img src="https://i.imgur.com/kdXUzu1.png" width="1000px"/>
# source: https://hackathonprojects.files.wordpress.com/2016/09/74911-image03.png

# %%
#Adding custom Layers
x = inc_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation="relu")(x)
x = Dropout(0.5)(x)
x = Dense(512, activation="relu")(x)
x = Dropout(0.5)(x)
x = Dense(512, activation="relu")(x)
predictions = Dense(2, activation="softmax")(x)

# %%
# creating the final model 
model_ = Model(inputs=inc_model.input, outputs=predictions)


for layer in model_.layers[:52]:
    layer.trainable = False

model_.compile(optimizer=SGD(lr=0.0001, momentum=0.9)
                    , loss='categorical_crossentropy'
                    , metrics=['accuracy'])

# %% [markdown]
# ### 4.2. Train Model

# %%
#saving the best model
checkpointer = ModelCheckpoint(filepath='weights.best.inc.male.hdf5', 
                               verbose=1, save_best_only=True)

# %%
hist = model_.fit_generator(train_generator
                     , validation_data = (x_valid, y_valid)
                      , steps_per_epoch= TRAINING_SAMPLES/BATCH_SIZE
                      , epochs= NUM_EPOCHS
                      , callbacks=[checkpointer]
                      , verbose=1
                    )
# Out:
# Epoch 1/40
# 1000/1000 [==============================] - 133s 133ms/step - loss: 0.5848 - acc: 0.6770 - val_loss: 0.3500 - val_acc: 0.8570
#
# Epoch 00001: val_loss improved from inf to 0.34996, saving model to weights.best.inc.male.hdf5
# Epoch 2/40
# 1000/1000 [==============================] - 119s 119ms/step - loss: 0.3738 - acc: 0.8375 - val_loss: 0.3315 - val_acc: 0.8620
#
# Epoch 00002: val_loss improved from 0.34996 to 0.33148, saving model to weights.best.inc.male.hdf5
# Epoch 3/40
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.3011 - acc: 0.8758 - val_loss: 0.3373 - val_acc: 0.8600
#
# Epoch 00003: val_loss did not improve from 0.33148
# Epoch 4/40
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.2557 - acc: 0.8973 - val_loss: 0.2535 - val_acc: 0.8935
#
# Epoch 00004: val_loss improved from 0.33148 to 0.25352, saving model to weights.best.inc.male.hdf5
# Epoch 5/40
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.2429 - acc: 0.9041 - val_loss: 0.2491 - val_acc: 0.8965
#
# Epoch 00005: val_loss improved from 0.25352 to 0.24908, saving model to weights.best.inc.male.hdf5
# Epoch 6/40
# 1000/1000 [==============================] - 119s 119ms/step - loss: 0.2173 - acc: 0.9171 - val_loss: 0.2682 - val_acc: 0.8880
#
# Epoch 00006: val_loss did not improve from 0.24908
# Epoch 7/40
# 1000/1000 [==============================] - 122s 122ms/step - loss: 0.2002 - acc: 0.9219 - val_loss: 0.2788 - val_acc: 0.8825
#
# Epoch 00007: val_loss did not improve from 0.24908
# Epoch 8/40
# 1000/1000 [==============================] - 122s 122ms/step - loss: 0.1883 - acc: 0.9260 - val_loss: 0.3081 - val_acc: 0.8775
#
# Epoch 00008: val_loss did not improve from 0.24908
# Epoch 9/40
# 1000/1000 [==============================] - 123s 123ms/step - loss: 0.1790 - acc: 0.9270 - val_loss: 0.2760 - val_acc: 0.8885
#
# Epoch 00009: val_loss did not improve from 0.24908
# Epoch 10/40
# 1000/1000 [==============================] - 123s 123ms/step - loss: 0.1734 - acc: 0.9322 - val_loss: 0.2707 - val_acc: 0.8865
#
# Epoch 00010: val_loss did not improve from 0.24908
# Epoch 11/40
# 1000/1000 [==============================] - 121s 121ms/step - loss: 0.1588 - acc: 0.9424 - val_loss: 0.3123 - val_acc: 0.8730
#
# Epoch 00011: val_loss did not improve from 0.24908
# Epoch 12/40
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.1496 - acc: 0.9432 - val_loss: 0.2563 - val_acc: 0.8950
#
# Epoch 00012: val_loss did not improve from 0.24908
# Epoch 13/40
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.1438 - acc: 0.9496 - val_loss: 0.2971 - val_acc: 0.8785
#
# Epoch 00013: val_loss did not improve from 0.24908
# Epoch 14/40
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.1382 - acc: 0.9517 - val_loss: 0.2911 - val_acc: 0.8870
#
# Epoch 00014: val_loss did not improve from 0.24908
# Epoch 15/40
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.1303 - acc: 0.9543 - val_loss: 0.2376 - val_acc: 0.9055
#
# Epoch 00015: val_loss improved from 0.24908 to 0.23765, saving model to weights.best.inc.male.hdf5
# Epoch 16/40
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.1215 - acc: 0.9548 - val_loss: 0.2586 - val_acc: 0.9025
#
# Epoch 00016: val_loss did not improve from 0.23765
# Epoch 17/40
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.1141 - acc: 0.9582 - val_loss: 0.2817 - val_acc: 0.8945
#
# Epoch 00017: val_loss did not improve from 0.23765
# Epoch 18/40
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.1167 - acc: 0.9579 - val_loss: 0.2418 - val_acc: 0.9125
#
# Epoch 00018: val_loss did not improve from 0.23765
# Epoch 19/40
# 1000/1000 [==============================] - 119s 119ms/step - loss: 0.1021 - acc: 0.9638 - val_loss: 0.2330 - val_acc: 0.9170
#
# Epoch 00019: val_loss improved from 0.23765 to 0.23297, saving model to weights.best.inc.male.hdf5
# Epoch 20/40
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0918 - acc: 0.9685 - val_loss: 0.2201 - val_acc: 0.9270
#
# Epoch 00020: val_loss improved from 0.23297 to 0.22010, saving model to weights.best.inc.male.hdf5
# Epoch 21/40
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0900 - acc: 0.9694 - val_loss: 0.2555 - val_acc: 0.9145
#
# Epoch 00021: val_loss did not improve from 0.22010
# Epoch 22/40
# 1000/1000 [==============================] - 119s 119ms/step - loss: 0.0955 - acc: 0.9663 - val_loss: 0.2319 - val_acc: 0.9230
#
# Epoch 00022: val_loss did not improve from 0.22010
# Epoch 23/40
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0819 - acc: 0.9714 - val_loss: 0.2132 - val_acc: 0.9260
#
# Epoch 00024: val_loss improved from 0.22010 to 0.21324, saving model to weights.best.inc.male.hdf5
# Epoch 25/40
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0794 - acc: 0.9719 - val_loss: 0.1619 - val_acc: 0.9470
#
# Epoch 00028: val_loss improved from 0.17786 to 0.16193, saving model to weights.best.inc.male.hdf5
# Epoch 29/40
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0711 - acc: 0.9758 - val_loss: 0.1453 - val_acc: 0.9520
#
# Epoch 00030: val_loss improved from 0.16193 to 0.14528, saving model to weights.best.inc.male.hdf5
# Epoch 31/40
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0629 - acc: 0.9778 - val_loss: 0.2184 - val_acc: 0.9315
#
# Epoch 00032: val_loss did not improve from 0.14528
# Epoch 33/40
# 1000/1000 [==============================] - 116s 116ms/step - loss: 0.0554 - acc: 0.9799 - val_loss: 0.1923 - val_acc: 0.9425
#
# Epoch 00034: val_loss did not improve from 0.14528
# Epoch 35/40
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0637 - acc: 0.9784 - val_loss: 0.1896 - val_acc: 0.9425
#
# Epoch 00036: val_loss did not improve from 0.14528
# Epoch 37/40
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0640 - acc: 0.9782 - val_loss: 0.1527 - val_acc: 0.9505
#
# Epoch 00038: val_loss did not improve from 0.14528
# Epoch 39/40
# 1000/1000 [==============================] - 122s 122ms/step - loss: 0.0554 - acc: 0.9799 - val_loss: 0.1496 - val_acc: 0.9560
#
# Epoch 00040: val_loss did not improve from 0.14528

# %% [markdown]
# #### The best model after NUM_epech got an accuracy over the validation data of 95.60%.

# %%
# Plot loss function value through epochs
plt.figure(figsize=(18, 4))
plt.plot(hist.history['loss'], label = 'train')
plt.plot(hist.history['val_loss'], label = 'valid')
plt.legend()
plt.title('Loss Function')
plt.show()

# %%
# Plot accuracy through epochs
plt.figure(figsize=(18, 4))
plt.plot(hist.history['acc'], label = 'train')
plt.plot(hist.history['val_acc'], label = 'valid')
plt.legend()
plt.title('Accuracy')
plt.show()

# %% [markdown]
# ### 4.3. Model Evaluation

# %%
#load the best model
model_.load_weights('weights.best.inc.male.hdf5')

# %%
# Test Data
x_test, y_test = generate_df(2, 'Male', TEST_SAMPLES)


model_predictions = [np.argmax(model_.predict(feature)) for feature in x_test ]

#  test accuracy
test_accuracy = 100 * np.sum(np.array(model_predictions)==y_test) / len(model_predictions)
print('Model Evaluation')
print('Test accuracy: %.4f%%' % test_accuracy)
print('f1_score:', f1_score(y_test, model_predictions))
# Out:
# Model Evaluation
# Test accuracy: 94.5500%
# f1_score: 0.9430809399477806

# %% [markdown]
# ### 6. User interface ( credit-Shruti)  :)
#
# > Indented block

# %%
#dictionary to name the prediction
gender_target = {0: 'Female'
                , 1: 'Male'}

def img_to_display(filename):

    
    i = Image.open(filename)
    i.thumbnail((200, 200), Image.LANCZOS)
    
    with BytesIO() as buffer:
        i.save(buffer, 'jpeg')
        return base64.b64encode(buffer.getvalue()).decode()
    

def display_result(filename, prediction, target):
    '''
    Display the results in HTML
    
    '''

    gender = 'Male'
    gender_icon = "https://i.imgur.com/nxWan2u.png"
        
    if prediction[1] <= 0.5:
        gender_icon = "https://i.imgur.com/oAAb8rd.png"
        gender = 'Female'
            
    display_html = '''
    <div style="overflow: auto;  border: 2px solid #D8D8D8;
        padding: 5px; width: 420px;" >
        <img src="data:image/jpeg;base64,{}" style="float: left;" width="200" height="200">
        <div style="padding: 10px 0px 0px 20px; overflow: auto;">
            <img src="{}" style="float: left;" width="40" height="40">
            <h3 style="margin-left: 50px; margin-top: 2px;">{}</h3>
            <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">{} prob.</p>
            <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real Target: {}</p>
            <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Filename: {}</p>
        </div>
    </div>
    '''.format(img_to_display(filename)
               , gender_icon
               , gender
               , "{0:.2f}%".format(round(max(prediction)*100,2))
               , gender_target[target]
               , filename.split('/')[-1]
               )

    display(HTML(display_html))

# %%
def gender_prediction(filename):
    '''
    predict the gender
    
    input:
        filename: str of the file name
        
    return:
        array of the prob of the targets.
    
    '''
    
    im = cv2.imread(filename)
    im = cv2.resize(cv2.cvtColor(im, cv2.COLOR_BGR2RGB), (178, 218)).astype(np.float32) / 255.0
    im = np.expand_dims(im, axis =0)
    
    # prediction
    result = model_.predict(im)
    prediction = np.argmax(result)
    
    return result

# %%
   #display result

df_to_test = df_par_attr[(df_par_attr['partition'] == 2)].sample(8)

for index, target in df_to_test.iterrows():
    result = gender_prediction(images_folder + index)
    
    display_result(images_folder + index, result[0], target['Male'])
# Out:
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 420px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://i.imgur.com/oAAb8rd.png" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Female</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">99.99% prob.</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real Target: Female</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Filename: 186395.jpg</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 420px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://i.imgur.com/oAAb8rd.png" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Female</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">99.98% prob.</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real Target: Female</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Filename: 190949.jpg</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 420px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://i.imgur.com/oAAb8rd.png" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Female</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">100.00% prob.</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real Target: Female</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Filename: 185347.jpg</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 420px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://i.imgur.com/oAAb8rd.png" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Female</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">100.00% prob.</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real Target: Female</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Filename: 190458.jpg</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 420px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://i.imgur.com/oAAb8rd.png" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Female</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">99.80% prob.</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real Target: Female</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Filename: 201281.jpg</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 420px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://i.imgur.com/nxWan2u.png" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Male</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">98.49% prob.</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real Target: Male</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Filename: 189708.jpg</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 420px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://i.imgur.com/oAAb8rd.png" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Female</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">100.00% prob.</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real Target: Female</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Filename: 185168.jpg</p>
#         </div>
#     </div>
#     <div style="overflow: auto;  border: 2px solid #D8D8D8;
#         padding: 5px; width: 420px;" >
#         <img src="data:image/jpeg;base64,..." style="float: left;" width="200" height="200">
#         <div style="padding: 10px 0px 0px 20px; overflow: auto;">
#             <img src="https://i.imgur.com/oAAb8rd.png" style="float: left;" width="40" height="40">
#             <h3 style="margin-left: 50px; margin-top: 2px;">Female</h3>
#             <p style="margin-left: 50px; margin-top: -6px; font-size: 12px">100.00% prob.</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Real Target: Female</p>
#             <p style="margin-left: 50px; margin-top: -16px; font-size: 12px">Filename: 199162.jpg</p>
#         </div>
#     </div>
